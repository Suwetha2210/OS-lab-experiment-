# %% [markdown]
# <a href="https://colab.research.google.com/github/Suwetha2210/OS-lab-experiment-/blob/main/Paging_Technique_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile paging.c
# #include <stdio.h>
#
# int main()
# {
#     int pageSize, numPages;
#     int pageTable[20];
#     int logicalAddress;
#     int pageNumber, offset;
#     int physicalAddress;
#     int i;
#
#     printf("Enter Page Size: ");
#     scanf("%d", &pageSize);
#
#     printf("Enter Number of Pages: ");
#     scanf("%d", &numPages);
#
#     printf("\nEnter Page Table (Frame Number for each Page):\n");
#
#     for(i = 0; i < numPages; i++)
#     {
#         printf("Page %d -> Frame: ", i);
#         scanf("%d", &pageTable[i]);
#     }
#
#     printf("\nEnter Logical Address: ");
#     scanf("%d", &logicalAddress);
#
#     pageNumber = logicalAddress / pageSize;
#     offset = logicalAddress % pageSize;
#
#     if(pageNumber >= numPages)
#     {
#         printf("\nInvalid Logical Address\n");
#         return 0;
#     }
#
#     physicalAddress = (pageTable[pageNumber] * pageSize) + offset;
#
#     printf("\nPage Number     : %d", pageNumber);
#     printf("\nOffset          : %d", offset);
#     printf("\nFrame Number    : %d", pageTable[pageNumber]);
#     printf("\nPhysical Address: %d\n", physicalAddress);
#
#     return 0;
# }
# Out:
# Overwriting paging.c

# %%
# !gcc paging.c -o paging

# %%
# !./paging
# Out:
# Enter Page Size: 3
# Enter Number of Pages: 2
#
# Enter Page Table (Frame Number for each Page):
# Page 0 -> Frame: 2
# Page 1 -> Frame: 3
#
# Enter Logical Address: 1
#
# Page Number     : 0
# Offset          : 1
# Frame Number    : 2
# Physical Address: 7
