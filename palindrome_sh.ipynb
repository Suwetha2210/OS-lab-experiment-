# %% [markdown]
# <a href="https://colab.research.google.com/github/Suwetha2210/OS-lab-experiment-/blob/main/palindrome_sh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# #!/bin/bash
#
# # Program to check whether a string is a palindrome
#
# echo "ENTER THE STRING TO CHECK PALINDROME:"
# read str
#
# # Find the length of the string
# len=$(echo -n "$str" | wc -c)
#
# i=1
# j=$((len / 2))
#
# while [ $i -le $j ]
# do
#     # Extract characters from the beginning and end
#     k=$(echo "$str" | cut -c $i)
#     l=$(echo "$str" | cut -c $len)
#
#     # Compare the characters
#     if [ "$k" != "$l" ]
#     then
#         echo "$str is not a palindrome"
#         exit
#     fi
#
#     i=$((i + 1))
#     len=$((len - 1))
# done
#
# echo "$str is a palindrome"
# Out:
# ENTER THE STRING TO CHECK PALINDROME:
#  is a palindrome
