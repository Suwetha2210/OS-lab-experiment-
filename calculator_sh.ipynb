# %% [markdown]
# <a href="https://colab.research.google.com/github/Suwetha2210/OS-lab-experiment-/blob/main/calculator_sh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
#
# #!/bin/bash
#
# # Program to perform basic arithmetic operations using case statement
#
# echo "ENTER THE VALUE OF A:"
# read a
#
# echo "ENTER THE VALUE OF B:"
# read b
#
# echo "ENTER THE OPTION TO PERFORM"
# echo "1. ADDITION"
# echo "2. SUBTRACTION"
# echo "3. MULTIPLICATION"
# echo "4. DIVISION"
#
# read op
#
# case "$op" in
#     1)
#         echo "Result = $((a + b))"
#         ;;
#     2)
#         echo "Result = $((a - b))"
#         ;;
#     3)
#         echo "Result = $((a * b))"
#         ;;
#     4)
#         if [ "$b" -eq 0 ]; then
#             echo "Error: Division by zero is not allowed."
#         else
#             echo "Result = $((a / b))"
#         fi
#         ;;
#     *)
#         echo "Invalid Option"
#         ;;
# esac
# Out:
# ENTER THE VALUE OF A:
# ENTER THE VALUE OF B:
# ENTER THE OPTION TO PERFORM
# 1. ADDITION
# 2. SUBTRACTION
# 3. MULTIPLICATION
# 4. DIVISION
# Invalid Option
